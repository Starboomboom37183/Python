# %%
import numpy as np

# %%
# %matplotlib notebook

# %%
# %gui

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,...">

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
fig
# Out:
# <img src="data:image/png;base64,...">

# %%
from numpy.random import randn

# %%
plt.plot(randn(50).cumsum(),'k--')#发出绘图命令，会在最后一块子图上完成绘制,'k--'表示黑色虚线

# %%
_=ax1.hist(randn(100),bins = 20,color='b',alpha = 0.3)

# %%
ax2.scatter(np.arange(30),np.arange(30)+3*randn(30))

# %%
fig,axes = plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,...">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f57a3870e90>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f57a32c22d0>]], dtype=object)

# %%
axes[0,0]

# %%
fig,axes = plt.subplots(2,2,sharex = True,sharey=True)
#sharex和sharey表示具有相同的x轴和y轴
# Out:
# <img src="data:image/png;base64,...">

# %%
for i in range(2):
    for j in range(2):
        axes[i,j].hist(randn(500),bins=50,color='k',alpha = 0.5)
plt.subplots_adjust(wspace =0,hspace = 0)
plt.close()

# %%
plt.figure()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
plt.plot(randn(30).cumsum(),color = 'b',linestyle= 'dashed',marker = 'o')

# %%
plt.plot(randn(30).cumsum(),'k-',drawstyle='step-post',label = 'steps-post')

# %%
plt.legend(loc = 'best')

# %%
plt.close()

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,...">

# %%
import pandas as pd

# %%
data = pd.read_csv('/home/wangyong/python_learn_test/pydata-book/examples/spx.csv',index_col=0,parse_dates=True)
#index_col=0表示第一列作为行索引,parse_dates转换时间

# %%
data[:5]
# Out:
#                SPX
# 1990-02-01  328.79
# 1990-02-02  330.92
# 1990-02-05  331.85
# 1990-02-06  329.66
# 1990-02-07  333.75

# %%
spx = data['SPX']

# %%
spx[:5]
# Out:
# 1990-02-01    328.79
# 1990-02-02    330.92
# 1990-02-05    331.85
# 1990-02-06    329.66
# 1990-02-07    333.75
# Name: SPX, dtype: float64

# %%
spx.plot(ax=ax,style = 'k-')

# %%
from datetime import datetime

# %%
crisis_data = [(datetime(2007,10,11),'Peak of bull market'),(datetime(2008,3,12),'Bear Stearns Fails'),(datetime(2008,9,15),'Lehman Bankruptcy')]

# %%
crisis_data
# Out:
# [(datetime.datetime(2007, 10, 11, 0, 0), 'Peak of bull market'),
#  (datetime.datetime(2008, 3, 12, 0, 0), 'Bear Stearns Fails'),
#  (datetime.datetime(2008, 9, 15, 0, 0), 'Lehman Bankruptcy')]

# %%
for date,label in crisis_data:
    ax.annotate(label,xy = (date,spx.asof(date)+50),xytext = (date,spx.asof(date)+200),arrowprops = dict(facecolor='black'),horizontalalignment='left',verticalalignment = 'top')

# %%
ax.set_xlim(['1/1/2007','1/1/2011'])
# Out:
# (732677.0, 734138.0)

# %%
ax.set_ylim([600,1800])
# Out:
# (600, 1800)

# %%
ax.set_title('Important dates in 2008-2009 financial crisis')
